# %% [markdown]
# Servo Prediction using Linear Regression

# %% [markdown]
# Import Library

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Import Dataset

# %%
Mg=pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Servo%20Mechanism.csv')

# %%
Mg.head()
# Out:
#   Motor Screw  Pgain  Vgain  Class
# 0     E     E      5      4      4
# 1     B     D      6      5     11
# 2     D     D      4      3      6
# 3     B     A      3      2     48
# 4     D     B      6      5      6

# %%
Mg
# Out:
#     Motor Screw  Pgain  Vgain  Class
# 0       E     E      5      4      4
# 1       B     D      6      5     11
# 2       D     D      4      3      6
# 3       B     A      3      2     48
# 4       D     B      6      5      6
# ..    ...   ...    ...    ...    ...
# 162     B     C      3      2     44
# 163     B     E      3      1     40
# 164     C     D      4      3     25
# 165     A     B      3      2     44
# 166     A     A      6      5     20
#
# [167 rows x 5 columns]

# %%
Mg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Motor   167 non-null    object
#  1   Screw   167 non-null    object
#  2   Pgain   167 non-null    int64
#  3   Vgain   167 non-null    int64
#  4   Class   167 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 6.6+ KB

# %%
Mg.describe()
# Out:
#             Pgain       Vgain       Class
# count  167.000000  167.000000  167.000000
# mean     4.155689    2.538922   21.173653
# std      1.017770    1.369850   13.908038
# min      3.000000    1.000000    1.000000
# 25%      3.000000    1.000000   10.500000
# 50%      4.000000    2.000000   18.000000
# 75%      5.000000    4.000000   33.500000
# max      6.000000    5.000000   51.000000

# %%
Mg.columns
# Out:
# Index(['Motor', 'Screw', 'Pgain', 'Vgain', 'Class'], dtype='object')

# %%
Mg.shape
# Out:
# (167, 5)

# %%
Mg[['Motor']].value_counts()
# Out:
# Motor
# C        40
# A        36
# B        36
# E        33
# D        22
# Name: count, dtype: int64

# %%
Mg[['Screw']].value_counts()
# Out:
# Screw
# A        42
# B        35
# C        31
# D        30
# E        29
# Name: count, dtype: int64

# %% [markdown]
# Get Encoding of Categorical Features

# %%
Mg.replace({'Motor':{'A':0,'B':1,'C':2,'D':3,'E':4 }},inplace=True)

# %%
Mg.replace({'Screw':{'A':0,'B':1,'C':2,'D':3,'E':4}}, inplace=True)

# %% [markdown]
# Define Y(dependent or label or target variable) and X(independent or features or attribute variable)

# %%
Y=Mg['Class']

# %%
Y.shape
# Out:
# (167,)

# %%
Y
# Out:
# 0       4
# 1      11
# 2       6
# 3      48
# 4       6
#        ..
# 162    44
# 163    40
# 164    25
# 165    44
# 166    20
# Name: Class, Length: 167, dtype: int64

# %%
X=Mg[['Motor','Screw','Pgain','Vgain']]

# %%
X.shape
# Out:
# (167, 4)

# %%
X
# Out:
#      Motor  Screw  Pgain  Vgain
# 0        4      4      5      4
# 1        1      3      6      5
# 2        3      3      4      3
# 3        1      0      3      2
# 4        3      1      6      5
# ..     ...    ...    ...    ...
# 162      1      2      3      2
# 163      1      4      3      1
# 164      2      3      4      3
# 165      0      1      3      2
# 166      0      0      6      5
#
# [167 rows x 4 columns]

# %% [markdown]
# Get Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3, random_state=2529)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((116, 4), (51, 4), (116,), (51,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Get Model Prediction

# %%
Y_pred=lr.predict(X_test)

# %%
Y_pred.shape
# Out:
# (51,)

# %%
Y_pred
# Out:
# array([24.55945258, 30.98765106, 18.54485477, 25.51524243, 38.56082023,
#        23.52007775, 11.61947065, 20.03335614, 40.60404401, 41.7009556 ,
#        13.66269443, 26.01242807, 16.50163099, 16.54663453, 21.92598051,
#        22.52570646, -5.46449561, 30.68912392, 32.7323477 ,  1.41282941,
#        33.97718702, 31.63543611, 33.52806048, 30.04133887, 19.38557109,
#         6.49364826, 28.5528375 , 17.04382017, 25.06611589,  3.50411229,
#        30.59606128, 23.67067716, 35.72188367, 32.08456265, 12.46018697,
#         3.6547117 , 23.47201865, 33.03087484, 17.49294672, 37.61450804,
#        27.54898855, 22.07657992, 11.51387478,  9.470651  , 30.53852451,
#        28.64590014, 33.67865989,  4.60102388, 24.1198037 , 21.13026773,
#        25.71390094])

# %% [markdown]
# Get Model Evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(Y_test,Y_pred)
# Out:
# 66.03589175595563

# %%
mean_absolute_error(Y_test,Y_pred)
# Out:
# 7.190539677251235

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.6807245170563927

# %% [markdown]
# Get Visualization of Actual Vs Predicted Result

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('Actual')
plt.ylabel('predicted')
plt.title ('Actual vs Predicted')
plt.show()

# %% [markdown]
# Get Future Prediction

# %%
X_new=Mg.sample(1)

# %%
X_new
# Out:
#     Motor  Screw  Pgain  Vgain  Class
# 81      0      2      6      5     11

# %%
X_new.shape
# Out:
# (1, 5)

# %%
X_new=X_new.drop('Class',axis=1)

# %%
X_new
# Out:
#     Motor  Screw  Pgain  Vgain
# 81      0      2      6      5

# %%
Y_pred_new=lr.predict(X_new)

# %%
Y_pred_new
# Out:
# array([8.68747144])
